# %%
import pandas as pd

# %%
df = pd.read_csv("artists.csv", usecols = ['slug']).drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-903e3e688d07> in <module>
# ----> 1 df = pd.read_csv("artists.csv", usecols = ['slug']).drop_duplicates().to_list()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_list'

# %%
df['slug'].to_list()
# Out:
# ['luis-rincon',
#  'lea-goldman-art',
#  'philippe-perennou',
#  'laura-muolo',
#  'algis-berziunas',
#  'dariusz-klimczak',
#  'paul-coughlan',
#  'angelajohnsonart',
#  'ian-fifield',
#  'tim-knifton',
#  'adriana-dziuba',
#  'marin-victor',
#  'rosalind-forster',
#  'aleksey-vylusk',
#  'irina-rumyantseva',
#  'james-bassett',
#  'trukan8',
#  'christopher-gill',
#  'branislav-puletic',
#  'tokareva_art',
#  'tan-tolga-demirci',
#  'rubenabstract',
#  'julian-sutherland-beatson',
#  'laure-bury',
#  'dif-paints',
#  'shukina',
#  'lindacoppens',
#  'lu-west',
#  'paperdraper',
#  'loetitia-pillault',
#  'paul-narbutt',
#  'provider-a73',
#  'randy-hilliker',
#  'paul-martin',
#  'chin-h-shin',
#  'kerikimura',
#  'halee-roth',
#  'andrew-cottrell-artworks',
#  'lizzie',
#  'georgiivinogradov',
#  'una-hurst',
#  'lee-ellis',
#  'christina-bodnaruk',
#  'natalia-nosyk',
#  'ellen-von-wiegand',
#  'baldvin-ringsted',
#  'rorymitchell',
#  'russell-aisthorpe',
# ...

# %%
df.drop_duplicates()
# Out:
#                    slug
# 0           luis-rincon
# 1       lea-goldman-art
# 2     philippe-perennou
# 3           laura-muolo
# 4       algis-berziunas
# ...                 ...
# 6819      lee-jenkinson
# 6820       grant-pecoff
# 6821    yuko-montgomery
# 6822         don-bishop
# 6823     marta-zawadzka
#
# [6730 rows x 1 columns]
